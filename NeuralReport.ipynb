# %% [markdown]
# <a href="https://colab.research.google.com/github/IzaquielCordeiro/NeuralReport/blob/main/NeuralReport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **`Neural Report`**
# `by izaquiel.cordeiro@ccc.ufcg.edu.br`

# %% [markdown]
# ###Fetch code

# %%
#@markdown Imports
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/IzaquielCordeiro/NeuralReport.git
# !pip install -q klusta

import sys
sys.path.append('./NeuralReport')

from report import Report

# %% [markdown]
# ###Report

# %%
rep = Report()
display(rep)
# Out:
# Report(children=(_DataScreen(children=(VBox(children=(Output(layout=Layout(border='1px solid black', height='1…
